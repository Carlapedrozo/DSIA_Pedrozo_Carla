# %% [markdown]
# # TP03 – Python Librerías

# %% [markdown]
# ### carla pedrozo

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datos=np.array([1,2,3,4,5])
print(datos)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# 1\-pandas porque se utiliza para trabajar con datos estructurados

# %% [markdown]
# 2\-matplotlib porque se usa para crear gráficos

# %% [markdown]
# 3\-scikit\-learn porque se usa para modelos de aprendizaje automatizados

# %% [markdown]
# 4\-numpy porque se utiliza para trabajar con arreglos numéricos

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d444798c-8b6d-4028-a049-4db8dd10ff43' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
