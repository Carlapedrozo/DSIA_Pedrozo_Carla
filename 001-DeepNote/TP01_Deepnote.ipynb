# %% [markdown]
# #  TP01 \- Deepnote Pedrozo carla

# %% [markdown]
# Me llamo carla pedrozo, tengo 31 años\.

# %% [markdown]
# Trabajo en atención al cliente en correo argentino\.

# %% [markdown]
# Mis expectativas son adquirir más conocimientos ya que busco un cambio en cuanto a lo laboral\.

# %%
print("MI PRIMER NOTEBOOK EN DEEPNOTE")
# Out:
# MI PRIMER NOTEBOOK EN DEEPNOTE

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d444798c-8b6d-4028-a049-4db8dd10ff43' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
